# %% [markdown]
# <a href="https://colab.research.google.com/github/Khoroshai/ForgeColabServer/blob/main/ForgeColabServer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Forge Minecraft Server
# *This method is inspired from MineColab (https://github.com/thecoder-001/MineColab)*
#
# *It uses free ressources thanks to Google, do not abuse of it.*
#
# This method uses zipped saves files and zipped server folder to reduce transfer time and numbers with gdrive which improves greatly the process and might avoid the famous "Transport endpoint not connected" error caused by a kind of desync with gdrive, afaik.
#
# The world files and logs are saved to gdrive every 5 minutes.
#
# *Tested on 1.18.2 with around 80 mods*
#
# # Requirements
# - An open tab that will stay focused
# - A base vanilla minecraft server
# - A base Forge server
# - Mods
# - A Playit.gg account (free)
#
# # How to use
# 1) Put the base vanilla and Forge server in a folder and add the mods to it.
#
# 2) *Zip* this folder and upload it somewhere on your gdrive.
#
# 3) *Edit* the **Names&Paths** in the first cell.
#
# 4) *Run* only one time the first cell to set everything up.
#
# 5) (using Playit.gg) Follow the link to activate the tunnel. (You might wait a few seconds, just follow the instruction) In case it is not the first tunnel you open, you can click on *Create Tunnel* and then stop the creation as only the agent is necessary. **The URL to the server is on Playit.gg**. If the URL doesn't work, the IP should work.
#
# 6) *Launch* the **Start Server** cell as you wish. Stopping it will gently close the server. (Could raise an error but trying a second time will close normally with saving worlds, etc... in normal cases)
#
# 7) *Run* the **Stop Auto-saves** cell when the server is stopped. You can run it while the server is up to make it auto-run when the server stops.
#
# 8) (optional) You can run the very last cell to save any changes made to the server. (properties, config...)
#
# # Additional informations
#
# *MineColab* has a cell to create the base server on gdrive. You can run it and then download the folder to continue the creation (Forge + mods + zipping)
#
# To create the base Forge server, as of August 2023, you can execute a jar file found on their official website.
#
# The *run.sh* file, that you'll get with the Forge base, contains a command which includes a version that you'll compare with the one in the Notebook at the **Start Server** cell.
#
# The tunnel used in this Notebook is Playit but you can easily copy-paste Ngrok or Argo from *MineColab*. Just pay attention to the command slighty modified here.
#
#
#
#
# # Known issues
#
# - The **Stop Auto-saves** cell takes up to 5 minutes (saving interval) to complete. Run, stop, run is a work around by raising an error.
# Possible solution : use a subprocess to interrupt it more easily.
#
# - Sometimes the server console stops allowing inputs. This happens when the bottom timer also stops counting the running time despite the server being up.
#
# # To do
#
# - Add Ngrok and Argo.
# - Make a GUI.

# %%
from google.colab import drive
import shutil
import zipfile
import os
import re
import json

# ___Names&Paths setup___
pathToDrive = '/content/drive/My Drive/Minecraft-server/'
worldName = 'KSworld'
# Please, make an archive of the whole server on the pathToDrive for easy transfer
serverArchiveName = 'MC.zip'
colabserver_folder = '/content/Minecraft-server/' # should be the same name as the drive one
Overworld = worldName
Nether = worldName + '_nether'
End = worldName + '_the_end'

# ___Import everything from gdrive___
#drive.mount('/content/drive')
driveserver_archive = pathToDrive + serverArchiveName
with zipfile.ZipFile(driveserver_archive, 'r') as zip_ref :
  zip_ref.extractall(colabserver_folder)
print('Importing server done.')
try :
  driveworld = pathToDrive + worldName + '.zip'
  with zipfile.ZipFile(driveworld, 'r') as zip_ref :
    zip_ref.extractall(colabserver_folder + worldName)
  print('Importing Overworld done.')

  drivenether = pathToDrive + Nether + '.zip'
  with zipfile.ZipFile(drivenether, 'r') as zip_ref :
    zip_ref.extractall(colabserver_folder + Nether)
  print('Importing Nether done.')

  driveend = pathToDrive + End + '.zip'
  with zipfile.ZipFile(driveend, 'r') as zip_ref :
    zip_ref.extractall(colabserver_folder + End)
  print('Importing End done.')
except FileNotFoundError as NoWorldYet:
  print('No world to import yet.')

# ___Prepare the environment___
# Update the package lists
# !sudo apt update &>/dev/null && echo "apt cache successfully updated" || echo "apt cache update failed, you might receive stale packages"
# Install OpenJDK 17
# !wget -qO - https://adoptopenjdk.jfrog.io/adoptopenjdk/api/gpg/key/public | sudo apt-key add -
# !sudo add-apt-repository --yes https://adoptopenjdk.jfrog.io/adoptopenjdk/deb/ &>/dev/null || echo "Failed to add repo. Still can be ignored if openjdk17 gets installed."
# !sudo apt-get install openjdk-17-jre-headless &>/dev/null && echo "Yay! Openjdk17 has been successfully installed." || echo "Failed to install OpenJdk17."
# Perform java version check
java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'
if java_ver[0] == "17" :
  print("Openjdk17 is working correctly, you are good to go.")
else:
  print("Openjdk17 doesn't seems to be installed or isn't working, falling back to java", java_ver[0], ". You might experience reduced performance. Minecraft 1.17 and above might fail to launch.")

# Change directory to the Minecraft server folder
# %cd "/content/Minecraft-server"

# Import config file.
if os.path.isfile("colabconfig.json"):
  colabconfig = json.load(open("colabconfig.json"))
else:
  colabconfig = {"server_type": "generic"} # using default, if config doesn't exists.
  json.dump(colabconfig, open("colabconfig.json",'w'))

# Server jar names.
jar_list = {'paper': 'server.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'bukkit': 'craftbukkit.jar'}
jar_name = jar_list[colabconfig["server_type"]]

# Java arguments.
if colabconfig["server_type"] == "paper":
  server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"
else:
  server_flags = "" # aiker's flags might negatively impact performance on non-paper servers.
memory_allocation = "-Xmx8000M -Xms100M"

# Chose the tunnle service you want to use
# Available options: ngrok, argo, playit
tunnel_service = "playit"
print("Proceeding to use", tunnel_service)

if tunnel_service == "playit":
  ! curl -SsL https://playit-cloud.github.io/ppa/key.gpg | sudo apt-key add -
  ! sudo curl -SsL -o /etc/apt/sources.list.d/playit-cloud.list https://playit-cloud.github.io/ppa/playit-cloud.list
  ! sudo apt update &>/dev/null && sudo apt install playit &>/dev/null && echo "Playit.gg installed" || echo "Failed to install playit"
  print('Starting tunnel')
  ! playit > playit.log 2>&1 &

# Output the line with the URL to open the tunnel
  with open('playit.log', 'r') as tunnelfile:
    for _ in range(3):
        tunnelfile.readline()
    third_ligne = tunnelfile.readline()
    print(third_ligne)
# Out:
# Importing server done.
# Importing Overworld done.
# Importing Nether done.
# Importing End done.
# apt cache successfully updated
# Yay! Openjdk17 has been successfully installed.
# Openjdk17 is working correctly, you are good to go.
# /content/Minecraft-server
# Proceeding to use playit
# Warning: apt-key is deprecated. Manage keyring files in trusted.gpg.d instead (see apt-key(8)).
# OK
# Playit.gg installed
# Starting tunnel
# 2023-08-14T14:13:02.836333Z  INFO playit_agent_core::setup_config: generated claim url claim_url=https://playit.gg/claim/6663a9f10a

# %% [markdown]
# # Start Server

# %%
import threading
import time
import shutil
from datetime import datetime

# ___Launch the server with an auto-save to gdrive___
Running = True

# Auto-saving function
def run_saveToDrive_task():
    while Running == True:
        Timestamp = datetime.now().strftime("%H:%M:%S")
        print(f"[{Timestamp}] [Auto-save] Saving World & logs to {pathToDrive}")
        shutil.make_archive(pathToDrive + Overworld, 'zip', Overworld)
        shutil.make_archive(pathToDrive + Nether, 'zip', Nether)
        shutil.make_archive(pathToDrive + End, 'zip', End)
        shutil.copytree('logs', pathToDrive + 'logs', dirs_exist_ok=True)
        time.sleep(300)  # Wait 5 minutes

# Creating thread
Save_thread = threading.Thread(target=run_saveToDrive_task)
# Starting thread
Save_thread.start()
# Starting server | Please, check if the version matches with run.sh
! java $memory_allocation $server_flags @libraries/net/minecraftforge/forge/1.18.2-40.2.10/unix_args.txt nogui
# Start Vanilla server
#! java $memory_allocation $server_flags -jar $jar_name nogui
# Out:
# [12:07:10] [Auto-save] Saving World & logs to /content/drive/My Drive/Minecraft-server/
# [12:07:18] [main/INFO] [cp.mo.mo.Launcher/MODLAUNCHER]: ModLauncher running: args [--launchTarget, forgeserver, --fml.forgeVersion, 40.2.10, --fml.mcVersion, 1.18.2, --fml.forgeGroup, net.minecraftforge, --fml.mcpVersion, 20220404.173914, nogui]
# [12:07:18] [main/INFO] [cp.mo.mo.Launcher/MODLAUNCHER]: ModLauncher 9.1.3+9.1.3+main.9b69c82a starting: java version 17.0.8 by Private Build
# [12:07:18] [main/INFO] [mixin/]: SpongePowered MIXIN Subsystem Version=0.8.5 Source=union:/content/Minecraft-server/libraries/org/spongepowered/mixin/0.8.5/mixin-0.8.5.jar%2314!/ Service=ModLauncher Env=SERVER
# [12:07:19] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /content/Minecraft-server/libraries/net/minecraftforge/fmlcore/1.18.2-40.2.10/fmlcore-1.18.2-40.2.10.jar is missing mods.toml file
# [12:07:19] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /content/Minecraft-server/libraries/net/minecraftforge/javafmllanguage/1.18.2-40.2.10/javafmllanguage-1.18.2-40.2.10.jar is missing mods.toml file
# [12:07:20] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /content/Minecraft-server/libraries/net/minecraftforge/lowcodelanguage/1.18.2-40.2.10/lowcodelanguage-1.18.2-40.2.10.jar is missing mods.toml file
# [12:07:20] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /content/Minecraft-server/libraries/net/minecraftforge/mclanguage/1.18.2-40.2.10/mclanguage-1.18.2-40.2.10.jar is missing mods.toml file
# [12:07:20] [main/INFO] [ne.mi.fm.lo.mo.JarInJarDependencyLocator/]: Found 5 dependencies adding them to mods collection
# [12:07:34] [main/INFO] [mixin/]: Compatibility level set to JAVA_17
# [12:07:34] [main/INFO] [mixin/]: Successfully loaded Mixin Connector [tictim.paraglider.MixinConnector]
# [12:07:34] [main/INFO] [mixin/]: Successfully loaded Mixin Connector [de.maxhenkel.camera.MixinConnector]
# [12:07:34] [main/INFO] [cp.mo.mo.LaunchServiceHandler/MODLAUNCHER]: Launching target 'forgeserver' with arguments [nogui]
# [12:07:34] [main/INFO] [Rubidium/]: Loaded configuration file for Rubidium: 28 options available, 0 override(s) found
# [12:07:34] [main/WARN] [mixin/]: Reference map 'untamedwilds.refmap.json' for untamedwilds.mixins.json could not be read. If this is a development environment you can ignore this message
# [12:07:35] [main/WARN] [mixin/]: Reference map 'creativecore.mixins.refmap.json' for creativecore.mixins.json could not be read. If this is a development environment you can ignore this message
# [12:08:08] [modloading-worker-0/INFO] [paucal/]: Hello PAUCAL! This is FORGE!
# [12:08:11] [PAUCAL Contributors Loading Thread/INFO] [paucal/]: Successfully loaded 41 contributors
# [12:08:14] [modloading-worker-0/INFO] [un.UntamedWilds/]: Loading compatibility module with Patchouli
# [12:08:16] [modloading-worker-0/INFO] [videoplayer/]: Initializing mod...
# [12:08:18] [modloading-worker-0/INFO] [ne.mi.co.ForgeMod/FORGEMOD]: Forge mod loading, version 40.2.10, for MC 1.18.2 with MCP 20220404.173914
# [12:08:18] [modloading-worker-0/INFO] [ne.mi.co.MinecraftForge/FORGE]: MinecraftForge v40.2.10 Initialized
# [12:08:18] [modloading-worker-0/INFO] [de.ke.ko.Konkrete/]: [KONKRETE] Successfully initialized!
# [12:08:18] [modloading-worker-0/INFO] [de.ke.ko.Konkrete/]: [KONKRETE] Server-side libs ready to use!
# [12:08:23] [modloading-worker-0/INFO] [th.ko.te.KotlinForForge/]: Kotlin For Forge Enabled!
# [12:08:23] [modloading-worker-0/INFO] [co.tt.re.AbstractRegistrate/]: Detected new forge version, registering events reflectively.
# [12:08:30] [modloading-worker-0/INFO] [mo.pi.bl.BlockCarpentryMain/]: Registering all blocks and items from BlockCarpentry
# [12:08:31] [modloading-worker-0/INFO] [mo.pi.bl.se.Registration/]: Registering blocks copy BlockCarpentry
# [12:08:31] [modloading-worker-0/INFO] [mo.pi.bl.se.Registration/]: Registering items copy BlockCarpentry
# [12:08:31] [modloading-worker-0/INFO] [mo.pi.bl.se.Registration/]: Registering tiles copy BlockCarpentry
# [12:08:31] [modloading-worker-0/INFO] [mo.pi.bl.se.Registration/]: Registering containers copy BlockCarpentry
# [12:08:31] [modloading-worker-0/INFO] [mo.pi.bl.se.Registration/]: Registering points of interest copy Blockcarpentry
# [12:08:31] [modloading-worker-0/INFO] [mo.pi.bl.BlockCarpentryMain/]: Registered all blocks and items from BlockCarpentry
# [12:08:31] [modloading-worker-0/INFO] [fancymenu/FancyMenu/]: [FANCYMENU] Loading v2.14.9 in server-side mode!
# [12:08:33] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id architectury:sync_ids
# [12:08:33] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftblibrary:edit_nbt_response
# [12:08:33] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbteams:open_gui
# [12:08:33] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbteams:update_settings
# [12:08:33] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbteams:send_message
# [12:08:33] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbteams:create_party
# [12:08:33] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbteams:player_gui_operation
# [12:08:33] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id itemfilters:main/14e7fa1454283aec8ae811ef844ada28
# [12:08:33] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id itemfilters:main/8f6a899247753217b9d86ab427a2b279
# [12:08:34] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:submit_task
# [12:08:34] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:claim_reward
# [12:08:34] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:get_emergency_items
# [12:08:34] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:claim_all_rewards
# [12:08:34] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:claim_choice_reward
# [12:08:34] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:toggle_pinned
# [12:08:34] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:toggle_chapter_pinned
# [12:08:34] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:toggle_editing_mode
# [12:08:34] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:force_save
# [12:08:34] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:set_custom_image
# [12:08:34] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:task_screen_config_resp
# [12:08:34] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:change_progress
# [12:08:34] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:create_object
# [12:08:34] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:create_task_at
# [12:08:34] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:delete_object
# [12:08:34] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:edit_object
# [12:08:34] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:move_chapter
# [12:08:34] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:move_quest
# [12:08:34] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:change_chapter_group
# [12:08:34] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:move_chapter_group
# [12:08:34] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:copy_quest
# [12:08:34] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:copy_chapter_image
# [12:09:27] [main/INFO] [ne.mi.re.GameData/]: Potentially Dangerous alternative prefix `minecraft` for name `lantern`, expected `additionallanterns`. This could be a intended override, but in most cases indicates a broken mod.
# [12:09:29] [main/INFO] [ne.mi.re.GameData/]: Potentially Dangerous alternative prefix `minecraft` for name `shulker_shell`, expected `supplementaries`. This could be a intended override, but in most cases indicates a broken mod.
# [12:09:33] [main/INFO] [ne.mi.re.GameData/]: Potentially Dangerous alternative prefix `minecraft` for name `milk`, expected `forge`. This could be a intended override, but in most cases indicates a broken mod.
# [12:09:33] [main/INFO] [ne.mi.re.GameData/]: Potentially Dangerous alternative prefix `minecraft` for name `flowing_milk`, expected `forge`. This could be a intended override, but in most cases indicates a broken mod.
# [12:09:38] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class com.github.alexthe666.alexsmobs.entity.EntityLeafcutterAnt from class com.github.alexthe666.alexsmobs.entity.EntityDevilsHolePupfish
# [12:09:38] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class com.github.alexthe666.alexsmobs.entity.EntityMantisShrimp from class com.github.alexthe666.alexsmobs.entity.EntitySkelewag
# [12:09:39] [modloading-worker-0/INFO] [un.UntamedWilds/]: Registering Packets!
# [12:09:39] [modloading-worker-0/INFO] [CPM/]: Customizable Player Models Initialized
# [12:09:39] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [roleplayplus] Starting version check at https://raw.githubusercontent.com/marzales23/RoleplayPlus/main/RoleplayPlus%20Update%20Checker.json
# [12:09:39] [modloading-worker-0/INFO] [voicechat/]: Compatibility version 17
# [12:09:40] [modloading-worker-0/INFO] [voicechat/]: Loading plugins
# [12:09:40] [modloading-worker-0/INFO] [voicechat/]: Loaded 1 plugin(s)
# [12:09:40] [modloading-worker-0/INFO] [voicechat/]: Initializing plugins
# [12:09:40] [modloading-worker-0/INFO] [CPM-SVC Compat/]: CPM voice chat plugin initialized!
# [12:09:40] [modloading-worker-0/INFO] [voicechat/]: Initialized 1 plugin(s)
# [12:09:40] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [roleplayplus] Found status: UP_TO_DATE Current: 1.0.6 Target: null
# [12:09:40] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [journeymap] Starting version check at https://forge.curseupdate.com/32274/journeymap
# [12:09:40] [modloading-worker-0/INFO] [voicechat/]: Registering events for cpmsvcc
# [12:09:40] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [journeymap] Found status: UP_TO_DATE Current: 5.9.7 Target: null
# [12:09:40] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [controlling] Starting version check at https://updates.blamejared.com/get?n=controlling&gv=1.18.2
# [12:09:41] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [controlling] Found status: BETA Current: 9.0+23 Target: 9.0+23
# [12:09:41] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [cpm] Starting version check at https://raw.githubusercontent.com/tom5454/CustomPlayerModels/master/version-check.json
# [12:09:41] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [cpm] Found status: BETA Current: 0.6.9a Target: 0.6.9a
# [12:09:41] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [additional_lights] Starting version check at https://gist.githubusercontent.com/mgen256/59abe85e7950f2319e7538afe2f910ba/raw
# [12:09:41] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [additional_lights] Found status: UP_TO_DATE Current: 2.1.4 Target: null
# [12:09:41] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [forge] Starting version check at https://files.minecraftforge.net/net/minecraftforge/forge/promotions_slim.json
# [12:09:41] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [forge] Found status: AHEAD Current: 40.2.10 Target: null
# [12:09:41] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [corpse] Starting version check at https://maxhenkel.de/update/corpse.json
# [12:09:41] [modloading-worker-0/INFO] [mo.pi.bl.BlockCarpentryMain/]: Setting up BlockCarpentry mod
# [12:09:41] [modloading-worker-0/INFO] [po.by.BYG/]: BYG: "Common Setup" Event Complete!
# [12:09:41] [modloading-worker-0/INFO] [po.by.BYG/]: "/content/Minecraft-server/config/byg/end-biomes.json5" was read.
# [12:09:41] [modloading-worker-0/INFO] [po.by.BYG/]: "/content/Minecraft-server/config/byg/nether-biomes.json5" was read.
# [12:09:42] [modloading-worker-0/INFO] [po.by.BYG/]: "/content/Minecraft-server/config/byg/overworld/byg-overworld-biomes.json5" was read.
# [12:09:42] [modloading-worker-0/INFO] [po.by.BYG/]: "/content/Minecraft-server/config/byg/byg-biome-dictionary.json" was read.
# [12:09:42] [modloading-worker-0/INFO] [po.by.BYG/]: "/content/Minecraft-server/config/byg/surface_rules/nether_surface_rules.json5" was read.
# [12:09:42] [modloading-worker-0/INFO] [po.by.BYG/]: "/content/Minecraft-server/config/byg/surface_rules/overworld_surface_rules.json5" was read.
# [12:09:42] [modloading-worker-0/INFO] [po.by.BYG/]: "/content/Minecraft-server/config/byg/surface_rules/end_surface_rules.json5" was read.
# [12:09:42] [modloading-worker-0/INFO] [po.by.BYG/]: "/content/Minecraft-server/config/byg/growing-patterns.json5" was read.
# [12:09:42] [modloading-worker-0/INFO] [po.by.BYG/]: "/content/Minecraft-server/config/byg/trades.json5" was read.
# [12:09:42] [modloading-worker-0/INFO] [po.by.BYG/]: "/content/Minecraft-server/config/byg/settings.json5" was read.
# [12:09:42] [modloading-worker-0/INFO] [po.by.BYG/]: "/content/Minecraft-server/config/byg/biomepedia.json5" was read.
# [12:09:42] [modloading-worker-0/INFO] [po.by.BYG/]: Created compressed zip back up for "/content/Minecraft-server/config/byg" in "/content/Minecraft-server/config/byg/backups/last_working_configs_backup.zip"
# [12:09:42] [modloading-worker-0/INFO] [po.by.BYG/]: BYG: Added strippable Blocks...
# [12:09:42] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [corpse] Found status: UP_TO_DATE Current: 1.18.2-1.0.1 Target: null
# [12:09:42] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [voicechat] Starting version check at https://maxhenkel.de/update/voicechat.json
# [12:09:42] [main/INFO] [journeymap/]: Initializing Packet Registries
# [12:09:42] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [voicechat] Found status: OUTDATED Current: 1.18.2-2.4.15 Target: 1.18.2-2.4.18
# [12:09:42] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [flywheel] Starting version check at https://api.modrinth.com/updates/flywheel/forge_updates.json
# [12:09:43] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [flywheel] Found status: AHEAD Current: 0.6.9-101 Target: null
# [12:09:43] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [camera] Starting version check at https://maxhenkel.de/update/camera.json
# [12:09:43] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [camera] Found status: UP_TO_DATE Current: 1.18.2-1.0.6 Target: null
# [12:09:43] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [securitycraft] Starting version check at https://www.github.com/Geforce132/SecurityCraft/raw/master/Updates/Forge.json
# [12:09:43] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [securitycraft] Found status: UP_TO_DATE Current: 1.9.7 Target: null
# [12:09:43] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [morevanillaarmor] Starting version check at https://assets.melanx.de/updates/morevanillaarmor.json
# [12:09:43] [main/INFO] [ne.me.su.Supplementaries/]: Finished mod setup in: 484 ms
# [12:09:44] [main/INFO] [po.by.BYG/]: Initializing BYG network...
# [12:09:44] [main/INFO] [po.by.BYG/]: Initialized BYG network!
# [12:09:44] [main/INFO] [terrablender/]: Registered region minecraft:overworld to index 0 for type OVERWORLD
# [12:09:44] [main/INFO] [terrablender/]: Registered region minecraft:nether to index 0 for type NETHER
# [12:09:44] [main/INFO] [terrablender/]: Registered region byg:region_0 to index 1 for type OVERWORLD
# [12:09:44] [main/INFO] [terrablender/]: Registered region byg:region_1 to index 2 for type OVERWORLD
# [12:09:44] [main/INFO] [terrablender/]: Registered region byg:region_2 to index 3 for type OVERWORLD
# [12:09:44] [main/INFO] [terrablender/]: Registered region byg:region_3 to index 4 for type OVERWORLD
# [12:09:44] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [morevanillaarmor] Found status: UP_TO_DATE Current: 1.18.2-3.1.2 Target: null
# [12:09:44] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [cfm] Starting version check at https://mrcrayfish.com/modupdatejson?id=cfm
# [12:09:44] [modloading-worker-0/INFO] [CPM/]: Customizable Player Models API initialized: Loaded plugins: (1)
# 	cpmsvcc
#
# [12:09:44] [modloading-worker-0/INFO] [mo.pi.bl.BlockCarpentryMain/]: Processing InterModCommunication
# [12:09:44] [modloading-worker-0/INFO] [mo.pi.bl.BlockCarpentryMain/]: Processed InterModCommunication
# [12:09:44] [modloading-worker-0/INFO] [hexcasting/]: Loaded 144 regular patterns, 14 per-world patterns, and 2 special handlers.
# [12:09:44] [modloading-worker-0/INFO] [Waila/]: Start loading plugin at mcp.mobius.waila.addons.core.CorePlugin
# [12:09:44] [modloading-worker-0/INFO] [Waila/]: Start loading plugin at de.maxhenkel.corpse.integration.waila.PluginCorpse
# [12:09:44] [modloading-worker-0/INFO] [Waila/]: Start loading plugin at net.blay09.mods.waystones.compat.WailaProvider
# [12:09:44] [modloading-worker-0/INFO] [Waila/]: Start loading plugin at snownee.jade.VanillaPlugin
# [12:09:44] [modloading-worker-0/INFO] [Waila/]: Start loading plugin at de.maxhenkel.camera.integration.waila.PluginCamera
# [12:09:44] [modloading-worker-0/INFO] [Waila/]: Start loading plugin at net.geforcemods.securitycraft.compat.waila.WailaDataProvider
# [12:09:44] [modloading-worker-0/INFO] [Waila/]: Start loading plugin at com.ferreusveritas.dynamictrees.compat.waila.WailaCompat
# [12:09:44] [main/INFO] [po.by.BYG/]: BYG: Compostable Blocks Added!
# [12:09:44] [main/INFO] [po.by.BYG/]: BYG: Added tillables!
# [12:09:44] [main/INFO] [po.by.BYG/]: BYG: Added Flammables!
# [12:09:44] [main/INFO] [po.by.BYG/]: BYG: "Load Complete" Event Complete!
# [12:09:44] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [cfm] Found status: BETA Current: 7.0.0-pre35 Target: 7.0.0-pre35
# [12:09:44] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [codechickenlib] Starting version check at https://version-check.covers1624.net/check/?mod=CodeChickenLib&mc=1.18.2
# [12:09:45] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [codechickenlib] Found status: UP_TO_DATE Current: 4.1.4.488 Target: null
# [12:09:45] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [dynamictrees] Starting version check at https://github.com/DynamicTreesTeam/DynamicTreesVersionInfo/blob/master/DynamicTrees.json?raw=true
# [12:09:45] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [dynamictrees] Found status: AHEAD Current: 1.18.2-1.0.3 Target: null
# [12:09:45] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [mcwlights] Starting version check at https://raw.githubusercontent.com/sketchmacaw/macawsmods/master/lights.json
# [12:09:45] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [mcwlights] Found status: UP_TO_DATE Current: 1.0.6 Target: null
# [12:10:16] [main/INFO] [mojang/YggdrasilAuthenticationService]: Environment: authHost='https://authserver.mojang.com', accountsHost='https://api.mojang.com', sessionHost='https://sessionserver.mojang.com', servicesHost='https://api.minecraftservices.com', name='PROD'
# [12:10:44] [main/WARN] [minecraft/VanillaPackResources]: Assets URL 'union:/content/Minecraft-server/libraries/net/minecraft/server/1.18.2-20220404.173914/server-1.18.2-20220404.173914-srg.jar%23123!/assets/.mcassetsroot' uses unexpected schema
# [12:10:44] [main/WARN] [minecraft/VanillaPackResources]: Assets URL 'union:/content/Minecraft-server/libraries/net/minecraft/server/1.18.2-20220404.173914/server-1.18.2-20220404.173914-srg.jar%23123!/data/.mcassetsroot' uses unexpected schema
# [12:10:44] [main/INFO] [ne.me.su.Supplementaries/]: Generated runtime SERVER_DATA for pack Supplementaries Generated Pack in: 155 ms
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [teleport, location] and [teleport, destination] with inputs: [0.1 -0.5 .9, 0 0 0]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [teleport, location] and [teleport, targets] with inputs: [0.1 -0.5 .9, 0 0 0]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [teleport, destination] and [teleport, targets] with inputs: [Player, 0123, @e, dd12be42-52a9-4a91-a8a1-11c01849e498]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [teleport, targets] and [teleport, destination] with inputs: [Player, 0123, dd12be42-52a9-4a91-a8a1-11c01849e498]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [teleport, targets, location] and [teleport, targets, destination] with inputs: [0.1 -0.5 .9, 0 0 0]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [ftbteams, info, server_id] and [ftbteams, info, team] with inputs: [server_id]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, setskin, -f] and [cpm, setskin, target] with inputs: [-f]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, setskin, -t] and [cpm, setskin, target] with inputs: [-t]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, setskin, -r] and [cpm, setskin, target] with inputs: [-r]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, entity, limit, max] and [cpm, scaling, entity, limit, min] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, entity, limit, max] and [cpm, scaling, entity, limit, target] with inputs: [0, -1, -.5, 1.2, .5, -1234.56]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, entity, limit, min] and [cpm, scaling, entity, limit, max] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, entity, limit, min] and [cpm, scaling, entity, limit, target] with inputs: [0, -1, -.5, 1.2, .5, -1234.56]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, entity, limit, target, max] and [cpm, scaling, entity, limit, target, min] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, entity, limit, target, min] and [cpm, scaling, entity, limit, target, max] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, entity, enabled, enable] and [cpm, scaling, entity, enabled, target] with inputs: [true, false]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, eye_height, limit, max] and [cpm, scaling, eye_height, limit, min] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, eye_height, limit, max] and [cpm, scaling, eye_height, limit, target] with inputs: [0, -1, -.5, 1.2, .5, -1234.56]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, eye_height, limit, min] and [cpm, scaling, eye_height, limit, max] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, eye_height, limit, min] and [cpm, scaling, eye_height, limit, target] with inputs: [0, -1, -.5, 1.2, .5, -1234.56]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, eye_height, limit, target, max] and [cpm, scaling, eye_height, limit, target, min] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, eye_height, limit, target, min] and [cpm, scaling, eye_height, limit, target, max] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, eye_height, enabled, enable] and [cpm, scaling, eye_height, enabled, target] with inputs: [true, false]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, hitbox_width, limit, max] and [cpm, scaling, hitbox_width, limit, min] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, hitbox_width, limit, max] and [cpm, scaling, hitbox_width, limit, target] with inputs: [0, -1, -.5, 1.2, .5, -1234.56]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, hitbox_width, limit, min] and [cpm, scaling, hitbox_width, limit, max] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, hitbox_width, limit, min] and [cpm, scaling, hitbox_width, limit, target] with inputs: [0, -1, -.5, 1.2, .5, -1234.56]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, hitbox_width, limit, target, max] and [cpm, scaling, hitbox_width, limit, target, min] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, hitbox_width, limit, target, min] and [cpm, scaling, hitbox_width, limit, target, max] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, hitbox_width, enabled, enable] and [cpm, scaling, hitbox_width, enabled, target] with inputs: [true, false]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, hitbox_height, limit, max] and [cpm, scaling, hitbox_height, limit, min] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, hitbox_height, limit, max] and [cpm, scaling, hitbox_height, limit, target] with inputs: [0, -1, -.5, 1.2, .5, -1234.56]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, hitbox_height, limit, min] and [cpm, scaling, hitbox_height, limit, max] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, hitbox_height, limit, min] and [cpm, scaling, hitbox_height, limit, target] with inputs: [0, -1, -.5, 1.2, .5, -1234.56]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, hitbox_height, limit, target, max] and [cpm, scaling, hitbox_height, limit, target, min] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, hitbox_height, limit, target, min] and [cpm, scaling, hitbox_height, limit, target, max] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, hitbox_height, enabled, enable] and [cpm, scaling, hitbox_height, enabled, target] with inputs: [true, false]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, third_person, limit, max] and [cpm, scaling, third_person, limit, min] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, third_person, limit, max] and [cpm, scaling, third_person, limit, target] with inputs: [0, -1, -.5, 1.2, .5, -1234.56]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, third_person, limit, min] and [cpm, scaling, third_person, limit, max] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, third_person, limit, min] and [cpm, scaling, third_person, limit, target] with inputs: [0, -1, -.5, 1.2, .5, -1234.56]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, third_person, limit, target, max] and [cpm, scaling, third_person, limit, target, min] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, third_person, limit, target, min] and [cpm, scaling, third_person, limit, target, max] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, third_person, enabled, enable] and [cpm, scaling, third_person, enabled, target] with inputs: [true, false]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, view_bobbing, limit, max] and [cpm, scaling, view_bobbing, limit, min] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, view_bobbing, limit, max] and [cpm, scaling, view_bobbing, limit, target] with inputs: [0, -1, -.5, 1.2, .5, -1234.56]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, view_bobbing, limit, min] and [cpm, scaling, view_bobbing, limit, max] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, view_bobbing, limit, min] and [cpm, scaling, view_bobbing, limit, target] with inputs: [0, -1, -.5, 1.2, .5, -1234.56]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, view_bobbing, limit, target, max] and [cpm, scaling, view_bobbing, limit, target, min] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, view_bobbing, limit, target, min] and [cpm, scaling, view_bobbing, limit, target, max] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, view_bobbing, enabled, enable] and [cpm, scaling, view_bobbing, enabled, target] with inputs: [true, false]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, motion, limit, max] and [cpm, scaling, motion, limit, min] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, motion, limit, max] and [cpm, scaling, motion, limit, target] with inputs: [0, -1, -.5, 1.2, .5, -1234.56]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, motion, limit, min] and [cpm, scaling, motion, limit, max] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, motion, limit, min] and [cpm, scaling, motion, limit, target] with inputs: [0, -1, -.5, 1.2, .5, -1234.56]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, motion, limit, target, max] and [cpm, scaling, motion, limit, target, min] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, motion, limit, target, min] and [cpm, scaling, motion, limit, target, max] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, motion, enabled, enable] and [cpm, scaling, motion, enabled, target] with inputs: [true, false]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, step_height, limit, max] and [cpm, scaling, step_height, limit, min] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, step_height, limit, max] and [cpm, scaling, step_height, limit, target] with inputs: [0, -1, -.5, 1.2, .5, -1234.56]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, step_height, limit, min] and [cpm, scaling, step_height, limit, max] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, step_height, limit, min] and [cpm, scaling, step_height, limit, target] with inputs: [0, -1, -.5, 1.2, .5, -1234.56]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, step_height, limit, target, max] and [cpm, scaling, step_height, limit, target, min] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, step_height, limit, target, min] and [cpm, scaling, step_height, limit, target, max] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, step_height, enabled, enable] and [cpm, scaling, step_height, enabled, target] with inputs: [true, false]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, flight_speed, limit, max] and [cpm, scaling, flight_speed, limit, min] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, flight_speed, limit, max] and [cpm, scaling, flight_speed, limit, target] with inputs: [0, -1, -.5, 1.2, .5, -1234.56]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, flight_speed, limit, min] and [cpm, scaling, flight_speed, limit, max] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, flight_speed, limit, min] and [cpm, scaling, flight_speed, limit, target] with inputs: [0, -1, -.5, 1.2, .5, -1234.56]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, flight_speed, limit, target, max] and [cpm, scaling, flight_speed, limit, target, min] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, flight_speed, limit, target, min] and [cpm, scaling, flight_speed, limit, target, max] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, flight_speed, enabled, enable] and [cpm, scaling, flight_speed, enabled, target] with inputs: [true, false]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, fall_damage, limit, max] and [cpm, scaling, fall_damage, limit, min] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, fall_damage, limit, max] and [cpm, scaling, fall_damage, limit, target] with inputs: [0, -1, -.5, 1.2, .5, -1234.56]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, fall_damage, limit, min] and [cpm, scaling, fall_damage, limit, max] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, fall_damage, limit, min] and [cpm, scaling, fall_damage, limit, target] with inputs: [0, -1, -.5, 1.2, .5, -1234.56]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, fall_damage, limit, target, max] and [cpm, scaling, fall_damage, limit, target, min] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, fall_damage, limit, target, min] and [cpm, scaling, fall_damage, limit, target, max] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, fall_damage, enabled, enable] and [cpm, scaling, fall_damage, enabled, target] with inputs: [true, false]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, reach, limit, max] and [cpm, scaling, reach, limit, min] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, reach, limit, max] and [cpm, scaling, reach, limit, target] with inputs: [0, -1, -.5, 1.2, .5, -1234.56]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, reach, limit, min] and [cpm, scaling, reach, limit, max] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, reach, limit, min] and [cpm, scaling, reach, limit, target] with inputs: [0, -1, -.5, 1.2, .5, -1234.56]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, reach, limit, target, max] and [cpm, scaling, reach, limit, target, min] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, reach, limit, target, min] and [cpm, scaling, reach, limit, target, max] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, reach, enabled, enable] and [cpm, scaling, reach, enabled, target] with inputs: [true, false]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, mining_speed, limit, max] and [cpm, scaling, mining_speed, limit, min] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, mining_speed, limit, max] and [cpm, scaling, mining_speed, limit, target] with inputs: [0, -1, -.5, 1.2, .5, -1234.56]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, mining_speed, limit, min] and [cpm, scaling, mining_speed, limit, max] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, mining_speed, limit, min] and [cpm, scaling, mining_speed, limit, target] with inputs: [0, -1, -.5, 1.2, .5, -1234.56]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, mining_speed, limit, target, max] and [cpm, scaling, mining_speed, limit, target, min] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, mining_speed, limit, target, min] and [cpm, scaling, mining_speed, limit, target, max] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, mining_speed, enabled, enable] and [cpm, scaling, mining_speed, enabled, target] with inputs: [true, false]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, attack_speed, limit, max] and [cpm, scaling, attack_speed, limit, min] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, attack_speed, limit, max] and [cpm, scaling, attack_speed, limit, target] with inputs: [0, -1, -.5, 1.2, .5, -1234.56]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, attack_speed, limit, min] and [cpm, scaling, attack_speed, limit, max] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, attack_speed, limit, min] and [cpm, scaling, attack_speed, limit, target] with inputs: [0, -1, -.5, 1.2, .5, -1234.56]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, attack_speed, limit, target, max] and [cpm, scaling, attack_speed, limit, target, min] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, attack_speed, limit, target, min] and [cpm, scaling, attack_speed, limit, target, max] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, attack_speed, enabled, enable] and [cpm, scaling, attack_speed, enabled, target] with inputs: [true, false]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, attack_knockback, limit, max] and [cpm, scaling, attack_knockback, limit, min] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, attack_knockback, limit, max] and [cpm, scaling, attack_knockback, limit, target] with inputs: [0, -1, -.5, 1.2, .5, -1234.56]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, attack_knockback, limit, min] and [cpm, scaling, attack_knockback, limit, max] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, attack_knockback, limit, min] and [cpm, scaling, attack_knockback, limit, target] with inputs: [0, -1, -.5, 1.2, .5, -1234.56]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, attack_knockback, limit, target, max] and [cpm, scaling, attack_knockback, limit, target, min] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, attack_knockback, limit, target, min] and [cpm, scaling, attack_knockback, limit, target, max] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, attack_knockback, enabled, enable] and [cpm, scaling, attack_knockback, enabled, target] with inputs: [true, false]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, attack_dmg, limit, max] and [cpm, scaling, attack_dmg, limit, min] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, attack_dmg, limit, max] and [cpm, scaling, attack_dmg, limit, target] with inputs: [0, -1, -.5, 1.2, .5, -1234.56]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, attack_dmg, limit, min] and [cpm, scaling, attack_dmg, limit, max] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, attack_dmg, limit, min] and [cpm, scaling, attack_dmg, limit, target] with inputs: [0, -1, -.5, 1.2, .5, -1234.56]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, attack_dmg, limit, target, max] and [cpm, scaling, attack_dmg, limit, target, min] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, attack_dmg, limit, target, min] and [cpm, scaling, attack_dmg, limit, target, max] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, attack_dmg, enabled, enable] and [cpm, scaling, attack_dmg, enabled, target] with inputs: [true, false]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, defense, limit, max] and [cpm, scaling, defense, limit, min] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, defense, limit, max] and [cpm, scaling, defense, limit, target] with inputs: [0, -1, -.5, 1.2, .5, -1234.56]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, defense, limit, min] and [cpm, scaling, defense, limit, max] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, defense, limit, min] and [cpm, scaling, defense, limit, target] with inputs: [0, -1, -.5, 1.2, .5, -1234.56]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, defense, limit, target, max] and [cpm, scaling, defense, limit, target, min] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, defense, limit, target, min] and [cpm, scaling, defense, limit, target, max] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, defense, enabled, enable] and [cpm, scaling, defense, enabled, target] with inputs: [true, false]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, health, limit, max] and [cpm, scaling, health, limit, min] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, health, limit, max] and [cpm, scaling, health, limit, target] with inputs: [0, -1, -.5, 1.2, .5, -1234.56]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, health, limit, min] and [cpm, scaling, health, limit, max] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, health, limit, min] and [cpm, scaling, health, limit, target] with inputs: [0, -1, -.5, 1.2, .5, -1234.56]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, health, limit, target, max] and [cpm, scaling, health, limit, target, min] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, health, limit, target, min] and [cpm, scaling, health, limit, target, max] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, health, enabled, enable] and [cpm, scaling, health, enabled, target] with inputs: [true, false]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, mob_visibility, limit, max] and [cpm, scaling, mob_visibility, limit, min] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, mob_visibility, limit, max] and [cpm, scaling, mob_visibility, limit, target] with inputs: [0, -1, -.5, 1.2, .5, -1234.56]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, mob_visibility, limit, min] and [cpm, scaling, mob_visibility, limit, max] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, mob_visibility, limit, min] and [cpm, scaling, mob_visibility, limit, target] with inputs: [0, -1, -.5, 1.2, .5, -1234.56]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, mob_visibility, limit, target, max] and [cpm, scaling, mob_visibility, limit, target, min] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, mob_visibility, limit, target, min] and [cpm, scaling, mob_visibility, limit, target, max] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, mob_visibility, enabled, enable] and [cpm, scaling, mob_visibility, enabled, target] with inputs: [true, false]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, width, limit, max] and [cpm, scaling, width, limit, min] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, width, limit, max] and [cpm, scaling, width, limit, target] with inputs: [0, -1, -.5, 1.2, .5, -1234.56]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, width, limit, min] and [cpm, scaling, width, limit, max] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, width, limit, min] and [cpm, scaling, width, limit, target] with inputs: [0, -1, -.5, 1.2, .5, -1234.56]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, width, limit, target, max] and [cpm, scaling, width, limit, target, min] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, width, limit, target, min] and [cpm, scaling, width, limit, target, max] with inputs: [1.2, .5]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, width, enabled, enable] and [cpm, scaling, width, enabled, target] with inputs: [true, false]
# [12:11:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [cpm, scaling, height, limit, max] and [cpm, scaling, height, limit, min] with inputs: [1.2, .5]
# ...
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# >....[1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# >....[1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:31] [Server thread/INFO] [minecraft/LoggerChunkProgressListener]: Time elapsed: 29129 ms
# [12:13:31] [Server thread/INFO] [minecraft/DedicatedServer]: Done (49.577s)! For help, type "help"
# [12:13:32] [Server thread/INFO] [ne.mi.se.pe.PermissionAPI/]: Successfully initialized permission handler forge:default_handler
# [12:13:32] [Server thread/INFO] [de.ge.au.ut.ServerRestarter/]: Saving restart status "EXCEPTION" to file
# [12:13:32] [Server thread/INFO] [FTB Quests/]: Loading quest progression data from /content/Minecraft-server/config/ftbquests/quests
# [12:13:32] [Server thread/INFO] [patchouli/]: Sending reload packet to clients
# [12:13:32] [VoiceChatServerThread/INFO] [voicechat/]: Voice chat server started at port 24454
# [12:13:32] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:32] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:32] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:32] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:32] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:32] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:32] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:32] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:32] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:32] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:32] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:32] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:32] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:32] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:32] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:32] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:32] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:33] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:33] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:33] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:33] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:33] [Server thread/WARN] [un.UntamedWilds/]: There's no species provided for the EntityType
# [12:13:35] [Server thread/WARN] [minecraft/MinecraftServer]: Can't keep up! Is the server overloaded? Running 2045ms or 40 ticks behind
# >....[12:17:47] [Auto-save] Saving World & logs to /content/drive/My Drive/Minecraft-server/
# [12:22:52] [Auto-save] Saving World & logs to /content/drive/My Drive/Minecraft-server/
# [12:27:56] [Auto-save] Saving World & logs to /content/drive/My Drive/Minecraft-server/
# [12:33:00] [Auto-save] Saving World & logs to /content/drive/My Drive/Minecraft-server/
# [12:38:04] [Auto-save] Saving World & logs to /content/drive/My Drive/Minecraft-server/
# [12:43:09] [Auto-save] Saving World & logs to /content/drive/My Drive/Minecraft-server/
# [12:48:13] [Auto-save] Saving World & logs to /content/drive/My Drive/Minecraft-server/
# [12:53:18] [Auto-save] Saving World & logs to /content/drive/My Drive/Minecraft-server/
# [12:58:23] [Auto-save] Saving World & logs to /content/drive/My Drive/Minecraft-server/
# [13:03:27] [Auto-save] Saving World & logs to /content/drive/My Drive/Minecraft-server/
# [13:08:31] [Auto-save] Saving World & logs to /content/drive/My Drive/Minecraft-server/
# [13:13:37] [Auto-save] Saving World & logs to /content/drive/My Drive/Minecraft-server/
# [13:18:41] [Auto-save] Saving World & logs to /content/drive/My Drive/Minecraft-server/
# [13:23:45] [Auto-save] Saving World & logs to /content/drive/My Drive/Minecraft-server/
# [13:24:51] [User Authenticator #1/INFO] [minecraft/ServerLoginPacketListenerImpl]: UUID of player Khoroshai is d29fac92-a84f-4399-96ac-f1139037c573
# [13:25:01] [Server thread/INFO] [ne.mi.co.AdvancementLoadFix/]: Using new advancement loading for net.minecraft.server.PlayerAdvancements@104ea2ef
# [13:25:01] [Server thread/INFO] [minecraft/PlayerList]: Khoroshai[/127.146.134.87:49205] logged in with entity id 183 at (424.2055847507347, 64.0, -738.854568523353)
# [13:25:01] [Server thread/INFO] [minecraft/DedicatedServer]: Khoroshai joined the game
# [13:25:02] [Server thread/INFO] [un.UntamedWilds/]: Firing player login event
# [13:25:02] [Server thread/INFO] [de.ge.au.ta.AutoRestartTask/]: Empty server timer stopped
# [13:25:02] [Server thread/INFO] [Waila/]: Syncing config to Khoroshai (d29fac92-a84f-4399-96ac-f1139037c573)
# [13:25:10] [Server thread/WARN] [minecraft/MinecraftServer]: Can't keep up! Is the server overloaded? Running 9292ms or 185 ticks behind
# [13:25:10] [Server thread/INFO] [voicechat/]: Received secret request of Khoroshai (17)
# [13:25:10] [Server thread/INFO] [voicechat/]: Sent secret to Khoroshai
# [13:25:47] [Server thread/WARN] [minecraft/MinecraftServer]: Can't keep up! Is the server overloaded? Running 22897ms or 457 ticks behind
# [13:26:10] [Server thread/WARN] [minecraft/MinecraftServer]: Can't keep up! Is the server overloaded? Running 7970ms or 159 ticks behind
# [13:26:41] [Server thread/WARN] [minecraft/MinecraftServer]: Can't keep up! Is the server overloaded? Running 2025ms or 40 ticks behind
# >....[13:28:50] [Auto-save] Saving World & logs to /content/drive/My Drive/Minecraft-server/
# [13:29:05] [Server thread/WARN] [minecraft/ServerLevel]: Tried to add entity enemyexpansion:sprinter but it was marked as removed already
# [13:31:24] [Server thread/INFO] [minecraft/DedicatedServer]: Khoroshai has made the advancement [The Andesite Age]
# >....[13:33:56] [Auto-save] Saving World & logs to /content/drive/My Drive/Minecraft-server/
# [13:34:06] [Server thread/WARN] [minecraft/ServerLevel]: Tried to add entity enemyexpansion:slugger but it was marked as removed already
# [13:35:34] [Server thread/INFO] [minecraft/DedicatedServer]: Khoroshai has made the advancement [Bonk!]
# >....[13:39:02] [Auto-save] Saving World & logs to /content/drive/My Drive/Minecraft-server/
# [13:44:08] [Auto-save] Saving World & logs to /content/drive/My Drive/Minecraft-server/
# [13:49:12] [Auto-save] Saving World & logs to /content/drive/My Drive/Minecraft-server/
# [13:54:17] [Auto-save] Saving World & logs to /content/drive/My Drive/Minecraft-server/
# [13:54:21] [Server thread/WARN] [minecraft/MinecraftServer]: Can't keep up! Is the server overloaded? Running 2005ms or 40 ticks behind
# [13:56:04] [Server thread/WARN] [minecraft/ServerLevel]: Tried to add entity enemyexpansion:sprinter but it was marked as removed already
# [13:57:19] [Server thread/INFO] [minecraft/ServerGamePacketListenerImpl]: Khoroshai lost connection: Disconnected
# [13:57:19] [Server thread/INFO] [minecraft/DedicatedServer]: Khoroshai left the game
# [13:57:19] [Server thread/INFO] [de.ge.au.ta.AutoRestartTask/]: Empty server timer started
# [13:57:19] [Server thread/INFO] [voicechat/]: Disconnecting client Khoroshai
# >....[13:58:26] [Server thread/INFO] [minecraft/MinecraftServer]: Stopping server
# [13:58:26] [Server thread/INFO] [minecraft/MinecraftServer]: Saving players
# [13:58:26] [Server thread/INFO] [minecraft/MinecraftServer]: Saving worlds
# [13:58:30] [Server thread/INFO] [minecraft/MinecraftServer]: Saving chunks for level 'ServerLevel[KSworld]'/minecraft:overworld
# [13:58:30] [Server thread/INFO] [minecraft/MinecraftServer]: Saving chunks for level 'ServerLevel[KSworld]'/minecraft:the_end
# [13:58:30] [Server thread/INFO] [minecraft/MinecraftServer]: Saving chunks for level 'ServerLevel[KSworld]'/minecraft:the_nether
# [13:58:30] [Server thread/INFO] [minecraft/MinecraftServer]: Saving chunks for level 'ServerLevel[KSworld]'/mahoutsukai:reality_marble
# [13:58:30] [Server thread/INFO] [minecraft/MinecraftServer]: ThreadedAnvilChunkStorage (KSworld): All chunks are saved
# [13:58:30] [Server thread/INFO] [minecraft/MinecraftServer]: ThreadedAnvilChunkStorage (DIM1): All chunks are saved
# [13:58:30] [Server thread/INFO] [minecraft/MinecraftServer]: ThreadedAnvilChunkStorage (DIM-1): All chunks are saved
# [13:58:30] [Server thread/INFO] [minecraft/MinecraftServer]: ThreadedAnvilChunkStorage (reality_marble): All chunks are saved
# [13:58:30] [Server thread/INFO] [minecraft/MinecraftServer]: ThreadedAnvilChunkStorage: All dimensions are saved
# [13:58:30] [Server thread/INFO] [de.ge.au.ut.ServerRestarter/]: Saving restart status "STOP" to file

# %% [markdown]
# **Stop Auto-saves or Do manual save**

# %%
# Stop the auto-saving (may take some time) | Rerun this cell for manual saving the worlds & logs
Running = False
Save_thread.join()

# Saves a last time after shutting down
shutil.make_archive(pathToDrive + Overworld, 'zip', Overworld)
shutil.make_archive(pathToDrive + Nether, 'zip', Nether)
shutil.make_archive(pathToDrive + End, 'zip', End)
#shutil.copytree(Overworld, destination_folder + worldName, dirs_exist_ok=True)
#shutil.copytree(Nether, destination_folder + Nether, dirs_exist_ok=True)
#shutil.copytree(End, destination_folder + End, dirs_exist_ok=True)
shutil.copytree('logs', pathToDrive + 'logs', dirs_exist_ok=True)
print("Done.")
# Out:
# Done.

# %% [markdown]
# **Save the whole server if you made changes**

# %%
import shutil
# Saving the whole server to drive
shutil.make_archive(pathToDrive + 'MC', 'zip', "/content/Minecraft-server/")
# Out:
# '/content/drive/My Drive/Minecraft-server/MC.zip'
